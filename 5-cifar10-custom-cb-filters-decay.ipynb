# %% [markdown]
# ### 데이터 전처리 수행.
# * 학습/검증/테스트 데이터 세트로 나누고 원-핫 인코딩 수행

# %%
import tensorflow as tf
import numpy as np
import pandas as pd

import random as python_random
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.datasets import cifar10

# seed 를 설정해서 학습시마다 동일한 결과 유도. 불행히도 의도한 대로 동작하지 않음. 
def set_random_seed(seed_value):
    np.random.seed(seed_value)
    python_random.seed(seed_value)
    tf.random.set_seed(seed_value)

# 0 ~ 1사이값의 float32로 변경하는 함수
def get_preprocessed_data(images, labels):
    
    # 학습과 테스트 이미지 array를 0~1 사이값으로 scale 및 float32 형 변형. 
    images = np.array(images/255.0, dtype=np.float32)
    labels = np.array(labels, dtype=np.float32)
    
    return images, labels

# 0 ~ 1사이값 float32로 변경하는 함수 호출 한 뒤 OHE 적용 
def get_preprocessed_ohe(images, labels):
    images, labels = get_preprocessed_data(images, labels)
    # OHE 적용 
    oh_labels = to_categorical(labels)
    return images, oh_labels

# 학습/검증/테스트 데이터 세트에 전처리 및 OHE 적용한 뒤 반환 
def get_train_valid_test_set(train_images, train_labels, test_images, test_labels, valid_size=0.15, random_state=2021):
    # 학습 및 테스트 데이터 세트를  0 ~ 1사이값 float32로 변경 및 OHE 적용. 
    train_images, train_oh_labels = get_preprocessed_ohe(train_images, train_labels)
    test_images, test_oh_labels = get_preprocessed_ohe(test_images, test_labels)
    
    # 학습 데이터를 검증 데이터 세트로 다시 분리
    tr_images, val_images, tr_oh_labels, val_oh_labels = train_test_split(train_images, train_oh_labels, test_size=valid_size, random_state=random_state)
    
    return (tr_images, tr_oh_labels), (val_images, val_oh_labels), (test_images, test_oh_labels ) 


# random seed는 2021로 고정.
set_random_seed(2021)
# CIFAR10 데이터 재 로딩 및 Scaling/OHE 전처리 적용하여 학습/검증/데이터 세트 생성. 
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
print(train_images.shape, train_labels.shape, test_images.shape, test_labels.shape)
(tr_images, tr_oh_labels), (val_images, val_oh_labels), (test_images, test_oh_labels) = \
    get_train_valid_test_set(train_images, train_labels, test_images, test_labels, valid_size=0.15, random_state=2021)

print(tr_images.shape, tr_oh_labels.shape, val_images.shape, val_oh_labels.shape, test_images.shape, test_oh_labels.shape)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 11s 0us/step
# (50000, 32, 32, 3) (50000, 1) (10000, 32, 32, 3) (10000, 1)
# (42500, 32, 32, 3) (42500, 10) (7500, 32, 32, 3) (7500, 10) (10000, 32, 32, 3) (10000, 10)

# %%
IMAGE_SIZE = 32

# %% [markdown]
# ### 모델 생성 함수 생성

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense , Conv2D , Dropout , Flatten , Activation, MaxPooling2D , GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam , RMSprop 
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau , EarlyStopping , ModelCheckpoint , LearningRateScheduler

def create_model(verbose=False):
    input_tensor = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))

    #x = Conv2D(filters=32, kernel_size=(5, 5), padding='valid', activation='relu')(input_tensor)
    x = Conv2D(filters=32, kernel_size=(3, 3), padding='same')(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(filters=32, kernel_size=(3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)

    x = Conv2D(filters=64, kernel_size=3, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(filters=64, kernel_size=3, padding='same')(x)
    x = Activation('relu')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=2)(x)

    x = Conv2D(filters=128, kernel_size=3, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(filters=128, kernel_size=3, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=2)(x)

    # cifar10의 클래스가 10개 이므로 마지막 classification의 Dense layer units갯수는 10
    x = Flatten(name='flatten')(x)
    x = Dropout(rate=0.5)(x)
    x = Dense(300, activation='relu', name='fc1')(x)
    x = Dropout(rate=0.3)(x)
    output = Dense(10, activation='softmax', name='output')(x)

    model = Model(inputs=input_tensor, outputs=output)
    
    if verbose:
        model.summary()
    
    return model

# %%
create_model(verbose=True)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  activation (Activation)     (None, 32, 32, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  activation_1 (Activation)   (None, 32, 32, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  activation_2 (Activation)   (None, 16, 16, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  activation_3 (Activation)   (None, 16, 16, 64)        0
#
#  activation_4 (Activation)   (None, 16, 16, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  batch_normalization_3 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  activation_5 (Activation)   (None, 8, 8, 128)         0
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_4 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  activation_6 (Activation)   (None, 8, 8, 128)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dropout (Dropout)           (None, 2048)              0
#
#  fc1 (Dense)                 (None, 300)               614700
#
#  dropout_1 (Dropout)         (None, 300)               0
#
#  output (Dense)              (None, 10)                3010
#
# =================================================================
# Total params: 906,254
# Trainable params: 905,486
# Non-trainable params: 768
# _________________________________________________________________

# %% [markdown]
# ### Learning Rate와 Early Stopping을 위한 Callback 생성
# * Learning rate 동적 변경은 ReduceLROnPlateau,  모델 Ealry Stopping은 EarlyStopping Callback을 이용.

# %%
# ModelCheckpoint를 동작시키기 전에 기존 저장된 모델은 모두 삭제 
# !rm *.hdf5
# Out:
# rm: cannot remove '*.hdf5': No such file or directory

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

model = create_model()
model.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# validation loss가 향상되는 모델만 저장.
mcp_cb = ModelCheckpoint(filepath='/kaggle/working/weights.{epoch:02d}-{val_loss:.2f}.hdf5', monitor='val_loss', 
                         save_best_only=True, save_weights_only=True, mode='min', period=1, verbose=0)

# 5번 iteration내에 validation loss가 향상되지 않으면 learning rate을 기존 learning rate * 0.2로 줄임.  
rlr_cb = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, mode='min', verbose=1)
# 10번 iteration내에 validation loss가 향상되지 않으면 더 이상 학습하지 않고 종료
ely_cb = EarlyStopping(monitor='val_loss', patience=10, mode='min', verbose=1)


history = model.fit(x=tr_images, y=tr_oh_labels, batch_size=32, epochs=30, shuffle=True,
                    validation_data=(val_images, val_oh_labels),  
                    callbacks=[mcp_cb, rlr_cb, ely_cb] )
# Out:
# Epoch 1/30
# 1329/1329 [==============================] - 23s 8ms/step - loss: 1.5555 - accuracy: 0.4341 - val_loss: 1.1744 - val_accuracy: 0.5721 - lr: 0.0010
# Epoch 2/30
# 1329/1329 [==============================] - 10s 7ms/step - loss: 1.1133 - accuracy: 0.6045 - val_loss: 1.5244 - val_accuracy: 0.5257 - lr: 0.0010
# Epoch 3/30
# 1329/1329 [==============================] - 10s 8ms/step - loss: 0.9243 - accuracy: 0.6752 - val_loss: 0.8075 - val_accuracy: 0.7181 - lr: 0.0010
# Epoch 4/30
# 1329/1329 [==============================] - 10s 8ms/step - loss: 0.8109 - accuracy: 0.7165 - val_loss: 0.8684 - val_accuracy: 0.7037 - lr: 0.0010
# Epoch 5/30
# 1329/1329 [==============================] - 11s 8ms/step - loss: 0.7248 - accuracy: 0.7495 - val_loss: 0.8496 - val_accuracy: 0.7144 - lr: 0.0010
# Epoch 6/30
# 1329/1329 [==============================] - 11s 8ms/step - loss: 0.6471 - accuracy: 0.7773 - val_loss: 0.6889 - val_accuracy: 0.7619 - lr: 0.0010
# Epoch 7/30
# 1329/1329 [==============================] - 10s 8ms/step - loss: 0.5868 - accuracy: 0.8005 - val_loss: 0.6667 - val_accuracy: 0.7737 - lr: 0.0010
# Epoch 8/30
# 1329/1329 [==============================] - 11s 8ms/step - loss: 0.5411 - accuracy: 0.8137 - val_loss: 0.6312 - val_accuracy: 0.7865 - lr: 0.0010
# Epoch 9/30
# 1329/1329 [==============================] - 10s 7ms/step - loss: 0.4933 - accuracy: 0.8308 - val_loss: 0.6133 - val_accuracy: 0.7976 - lr: 0.0010
# Epoch 10/30
# 1329/1329 [==============================] - 10s 8ms/step - loss: 0.4549 - accuracy: 0.8436 - val_loss: 0.6002 - val_accuracy: 0.8033 - lr: 0.0010
# Epoch 11/30
# 1329/1329 [==============================] - 10s 8ms/step - loss: 0.4160 - accuracy: 0.8560 - val_loss: 0.5629 - val_accuracy: 0.8163 - lr: 0.0010
# Epoch 12/30
# 1329/1329 [==============================] - 10s 7ms/step - loss: 0.3829 - accuracy: 0.8685 - val_loss: 0.5614 - val_accuracy: 0.8137 - lr: 0.0010
# Epoch 13/30
# 1329/1329 [==============================] - 10s 8ms/step - loss: 0.3572 - accuracy: 0.8760 - val_loss: 0.8596 - val_accuracy: 0.7371 - lr: 0.0010
# Epoch 14/30
# 1329/1329 [==============================] - 10s 8ms/step - loss: 0.3309 - accuracy: 0.8857 - val_loss: 0.6074 - val_accuracy: 0.8113 - lr: 0.0010
# Epoch 15/30
# 1329/1329 [==============================] - 10s 7ms/step - loss: 0.3069 - accuracy: 0.8943 - val_loss: 0.5472 - val_accuracy: 0.8324 - lr: 0.0010
# Epoch 16/30
# 1329/1329 [==============================] - 10s 7ms/step - loss: 0.2866 - accuracy: 0.8998 - val_loss: 0.5392 - val_accuracy: 0.8348 - lr: 0.0010
# Epoch 17/30
# 1329/1329 [==============================] - 10s 8ms/step - loss: 0.2670 - accuracy: 0.9077 - val_loss: 0.6382 - val_accuracy: 0.8108 - lr: 0.0010
# Epoch 18/30
# 1329/1329 [==============================] - 10s 7ms/step - loss: 0.2532 - accuracy: 0.9115 - val_loss: 0.6538 - val_accuracy: 0.8085 - lr: 0.0010
# Epoch 19/30
# 1329/1329 [==============================] - 10s 8ms/step - loss: 0.2393 - accuracy: 0.9168 - val_loss: 0.5720 - val_accuracy: 0.8249 - lr: 0.0010
# Epoch 20/30
# 1329/1329 [==============================] - 11s 8ms/step - loss: 0.2258 - accuracy: 0.9218 - val_loss: 0.6758 - val_accuracy: 0.8012 - lr: 0.0010
# Epoch 21/30
# 1322/1329 [============================>.] - ETA: 0s - loss: 0.2146 - accuracy: 0.9273
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 1329/1329 [==============================] - 10s 8ms/step - loss: 0.2146 - accuracy: 0.9272 - val_loss: 0.5914 - val_accuracy: 0.8239 - lr: 0.0010
# Epoch 22/30
# 1329/1329 [==============================] - 11s 8ms/step - loss: 0.1337 - accuracy: 0.9539 - val_loss: 0.5406 - val_accuracy: 0.8587 - lr: 2.0000e-04
# Epoch 23/30
# 1329/1329 [==============================] - 11s 8ms/step - loss: 0.1044 - accuracy: 0.9643 - val_loss: 0.5538 - val_accuracy: 0.8624 - lr: 2.0000e-04
# Epoch 24/30
# 1329/1329 [==============================] - 10s 8ms/step - loss: 0.0938 - accuracy: 0.9675 - val_loss: 0.5672 - val_accuracy: 0.8609 - lr: 2.0000e-04
# Epoch 25/30
# 1329/1329 [==============================] - 10s 7ms/step - loss: 0.0790 - accuracy: 0.9729 - val_loss: 0.5922 - val_accuracy: 0.8612 - lr: 2.0000e-04
# Epoch 26/30
# 1326/1329 [============================>.] - ETA: 0s - loss: 0.0747 - accuracy: 0.9739
# Epoch 26: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 1329/1329 [==============================] - 11s 8ms/step - loss: 0.0747 - accuracy: 0.9740 - val_loss: 0.6325 - val_accuracy: 0.8580 - lr: 2.0000e-04
# Epoch 26: early stopping

# %%
model.evaluate(test_images, test_oh_labels)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6621 - accuracy: 0.8496
# [0.6621254682540894, 0.8496000170707703]

# %%
# !ls -lia
# Out:
# total 39612
#    524294 drwxr-xr-x 3 root root    4096 Jul 30 23:54 .
# 268743683 drwxr-xr-x 5 root root    4096 Jul 30 22:43 ..
#    524295 drwxr-xr-x 2 root root    4096 Jul 30 22:44 .virtual_documents
#    524296 -rw-r--r-- 1 root root 3685024 Jul 30 23:51 weights.01-1.17.hdf5
#    524297 -rw-r--r-- 1 root root 3685024 Jul 30 23:52 weights.03-0.81.hdf5
#    524298 -rw-r--r-- 1 root root 3685024 Jul 30 23:52 weights.06-0.69.hdf5
#    524299 -rw-r--r-- 1 root root 3685024 Jul 30 23:52 weights.07-0.67.hdf5
#    524300 -rw-r--r-- 1 root root 3685024 Jul 30 23:52 weights.08-0.63.hdf5
#    524301 -rw-r--r-- 1 root root 3685024 Jul 30 23:53 weights.09-0.61.hdf5
#    524302 -rw-r--r-- 1 root root 3685024 Jul 30 23:53 weights.10-0.60.hdf5
#    524303 -rw-r--r-- 1 root root 3685024 Jul 30 23:53 weights.11-0.56.hdf5
#    524304 -rw-r--r-- 1 root root 3685024 Jul 30 23:53 weights.12-0.56.hdf5
#    524305 -rw-r--r-- 1 root root 3685024 Jul 30 23:54 weights.15-0.55.hdf5
#    524306 -rw-r--r-- 1 root root 3685024 Jul 30 23:54 weights.16-0.54.hdf5

# %% [markdown]
# ### 최적 weight를 모델로 재 로딩한 다음에 테스트 데이터로 다시 평가

# %%
model = create_model()
model.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
model.load_weights('/kaggle/working/weights.16-0.54.hdf5')

# %%
model.evaluate(test_images, test_oh_labels)
# Out:
# 313/313 [==============================] - 2s 4ms/step - loss: 0.5626 - accuracy: 0.8265
# [0.5625659823417664, 0.8264999985694885]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def show_history(history):
    plt.figure(figsize=(8, 4))
    plt.yticks(np.arange(0, 1, 0.05))
    plt.xticks(np.arange(0, 30, 2))
    plt.plot(history.history['accuracy'], label='train')
    plt.plot(history.history['val_accuracy'], label='valid')
    plt.legend()
    
show_history(history)

# %% [markdown]
# ### 필터의 개수를 증가시켜 테스트
# * Conv Layer의 필터를 기존보다 2배씩 증가
# * 맨 마지막 Conv는 512로 대폭 증가

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense , Conv2D , Dropout , Flatten , Activation, MaxPooling2D , GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam , RMSprop 
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau , EarlyStopping , ModelCheckpoint , LearningRateScheduler

input_tensor = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))

#x = Conv2D(filters=32, kernel_size=(5, 5), padding='valid', activation='relu')(input_tensor)
x = Conv2D(filters=64, kernel_size=(3, 3), padding='same')(input_tensor)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=64, kernel_size=(3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

x = Conv2D(filters=128, kernel_size=3, padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=128, kernel_size=3, padding='same')(x)
x = Activation('relu')(x)
x = Activation('relu')(x)
x = MaxPooling2D(pool_size=2)(x)

x = Conv2D(filters=256, kernel_size=3, padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=256, kernel_size=3, padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

# 512 filters Conv layer 추가
x = Conv2D(filters=512, kernel_size=3, padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = MaxPooling2D(pool_size=2)(x)

# cifar10의 클래스가 10개 이므로 마지막 classification의 Dense layer units갯수는 10
x = Flatten(name='flatten')(x)
x = Dropout(rate=0.5)(x)
x = Dense(300, activation='relu', name='fc1')(x)
x = Dropout(rate=0.3)(x)
output = Dense(10, activation='softmax', name='output')(x)

model = Model(inputs=input_tensor, outputs=output)

model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 64)        1792
#
#  batch_normalization_5 (Batc  (None, 32, 32, 64)       256
#  hNormalization)
#
#  activation_7 (Activation)   (None, 32, 32, 64)        0
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 64)        36928
#
#  batch_normalization_6 (Batc  (None, 32, 32, 64)       256
#  hNormalization)
#
#  activation_8 (Activation)   (None, 32, 32, 64)        0
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 128)       73856
#
#  batch_normalization_7 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  activation_9 (Activation)   (None, 16, 16, 128)       0
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 128)       147584
#
#  activation_10 (Activation)  (None, 16, 16, 128)       0
#
#  activation_11 (Activation)  (None, 16, 16, 128)       0
#
#  max_pooling2d_4 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 8, 8, 256)         295168
#
#  batch_normalization_8 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  activation_12 (Activation)  (None, 8, 8, 256)         0
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 256)         590080
#
#  batch_normalization_9 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  activation_13 (Activation)  (None, 8, 8, 256)         0
#
#  conv2d_12 (Conv2D)          (None, 8, 8, 512)         1180160
#
#  batch_normalization_10 (Bat  (None, 8, 8, 512)        2048
#  chNormalization)
#
#  activation_14 (Activation)  (None, 8, 8, 512)         0
#
#  max_pooling2d_5 (MaxPooling  (None, 4, 4, 512)        0
#  2D)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dropout_2 (Dropout)         (None, 8192)              0
#
#  fc1 (Dense)                 (None, 300)               2457900
#
#  dropout_3 (Dropout)         (None, 300)               0
#
#  output (Dense)              (None, 10)                3010
#
# =================================================================
# Total params: 4,791,598
# Trainable params: 4,789,038
# Non-trainable params: 2,560
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# 5번 iteration내에 validation loss가 향상되지 않으면 learning rate을 기존 learning rate * 0.2로 줄임.  
rlr_cb = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, mode='min', verbose=1)
# 10번 iteration내에 validation loss가 향상되지 않으면 더 이상 학습하지 않고 종료
ely_cb = EarlyStopping(monitor='val_loss', patience=10, mode='min', verbose=1)


history = model.fit(x=tr_images, y=tr_oh_labels, batch_size=32, epochs=30, shuffle=True,
                    validation_data=(val_images, val_oh_labels),  
                    callbacks=[rlr_cb, ely_cb] )
# Out:
# Epoch 1/30
# 1329/1329 [==============================] - 28s 12ms/step - loss: 1.9939 - accuracy: 0.2487 - val_loss: 1.8013 - val_accuracy: 0.3223 - lr: 0.0010
# Epoch 2/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 1.6248 - accuracy: 0.3476 - val_loss: 1.5823 - val_accuracy: 0.4177 - lr: 0.0010
# Epoch 3/30
# 1329/1329 [==============================] - 15s 11ms/step - loss: 1.4983 - accuracy: 0.3982 - val_loss: 1.3307 - val_accuracy: 0.4707 - lr: 0.0010
# Epoch 4/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 1.3971 - accuracy: 0.4482 - val_loss: 1.1170 - val_accuracy: 0.6260 - lr: 0.0010
# Epoch 5/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 1.3006 - accuracy: 0.4960 - val_loss: 1.0696 - val_accuracy: 0.6545 - lr: 0.0010
# Epoch 6/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 1.2117 - accuracy: 0.5324 - val_loss: 1.0238 - val_accuracy: 0.6619 - lr: 0.0010
# Epoch 7/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 1.0711 - accuracy: 0.5941 - val_loss: 0.9477 - val_accuracy: 0.6971 - lr: 0.0010
# Epoch 8/30
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.8738 - accuracy: 0.6912 - val_loss: 0.7046 - val_accuracy: 0.7699 - lr: 0.0010
# Epoch 9/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.7516 - accuracy: 0.7352 - val_loss: 0.7898 - val_accuracy: 0.7307 - lr: 0.0010
# Epoch 10/30
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.6392 - accuracy: 0.7789 - val_loss: 0.6622 - val_accuracy: 0.7919 - lr: 0.0010
# Epoch 11/30
# 1329/1329 [==============================] - 14s 10ms/step - loss: 0.5369 - accuracy: 0.8183 - val_loss: 0.7474 - val_accuracy: 0.7681 - lr: 0.0010
# Epoch 12/30
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.4536 - accuracy: 0.8481 - val_loss: 0.6256 - val_accuracy: 0.8084 - lr: 0.0010
# Epoch 13/30
# 1329/1329 [==============================] - 14s 10ms/step - loss: 0.3791 - accuracy: 0.8750 - val_loss: 0.5859 - val_accuracy: 0.8252 - lr: 0.0010
# Epoch 14/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.3220 - accuracy: 0.8933 - val_loss: 0.6868 - val_accuracy: 0.8023 - lr: 0.0010
# Epoch 15/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.2872 - accuracy: 0.9050 - val_loss: 0.5804 - val_accuracy: 0.8312 - lr: 0.0010
# Epoch 16/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.2481 - accuracy: 0.9190 - val_loss: 0.8557 - val_accuracy: 0.7988 - lr: 0.0010
# Epoch 17/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.2090 - accuracy: 0.9306 - val_loss: 0.6641 - val_accuracy: 0.8312 - lr: 0.0010
# Epoch 18/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.1868 - accuracy: 0.9392 - val_loss: 0.8278 - val_accuracy: 0.8159 - lr: 0.0010
# Epoch 19/30
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.1651 - accuracy: 0.9456 - val_loss: 0.7118 - val_accuracy: 0.8319 - lr: 0.0010
# Epoch 20/30
# 1325/1329 [============================>.] - ETA: 0s - loss: 0.1439 - accuracy: 0.9530
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.1443 - accuracy: 0.9529 - val_loss: 0.7921 - val_accuracy: 0.8215 - lr: 0.0010
# Epoch 21/30
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.0656 - accuracy: 0.9792 - val_loss: 0.6359 - val_accuracy: 0.8700 - lr: 2.0000e-04
# Epoch 22/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.0369 - accuracy: 0.9877 - val_loss: 0.7151 - val_accuracy: 0.8679 - lr: 2.0000e-04
# Epoch 23/30
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.0290 - accuracy: 0.9908 - val_loss: 0.7973 - val_accuracy: 0.8656 - lr: 2.0000e-04
# Epoch 24/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.0226 - accuracy: 0.9928 - val_loss: 0.7926 - val_accuracy: 0.8700 - lr: 2.0000e-04
# Epoch 25/30
# 1324/1329 [============================>.] - ETA: 0s - loss: 0.0214 - accuracy: 0.9932
# Epoch 25: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 1329/1329 [==============================] - 14s 10ms/step - loss: 0.0214 - accuracy: 0.9933 - val_loss: 0.8707 - val_accuracy: 0.8684 - lr: 2.0000e-04
# Epoch 25: early stopping

# %%
model.evaluate(test_images, test_oh_labels)
show_history(history)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.9576 - accuracy: 0.8639

# %% [markdown]
# ### 맨 마지막 Conv + MaxPooling 대신 맨 마지막 Conv의 Strides를 2로 하여 Feature map 조정

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense , Conv2D , Dropout , Flatten , Activation, MaxPooling2D , GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam , RMSprop 
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau , EarlyStopping , ModelCheckpoint , LearningRateScheduler

input_tensor = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))

x = Conv2D(filters=64, kernel_size=(3, 3), padding='same')(input_tensor)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=64, kernel_size=(3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

x = Conv2D(filters=128, kernel_size=3, padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=128, kernel_size=3, padding='same')(x)
x = Activation('relu')(x)
x = Activation('relu')(x)
x = MaxPooling2D(pool_size=2)(x)

x = Conv2D(filters=256, kernel_size=3, padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=256, kernel_size=3, padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

# 512 filters Conv layer 추가하되 이후 MaxPooling을 적용하지 않고 strides는 2로 변경하여 출력 feature map 크기 조정
x = Conv2D(filters=512, kernel_size=3, strides=2, padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)


# cifar10의 클래스가 10개 이므로 마지막 classification의 Dense layer units갯수는 10
x = Flatten(name='flatten')(x)
x = Dropout(rate=0.5)(x)
x = Dense(300, activation='relu', name='fc1')(x)
x = Dropout(rate=0.3)(x)
output = Dense(10, activation='softmax', name='output')(x)

model = Model(inputs=input_tensor, outputs=output)

model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 64)        1792
#
#  batch_normalization_11 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  activation_15 (Activation)  (None, 32, 32, 64)        0
#
#  conv2d_14 (Conv2D)          (None, 32, 32, 64)        36928
#
#  batch_normalization_12 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  activation_16 (Activation)  (None, 32, 32, 64)        0
#
#  max_pooling2d_6 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_15 (Conv2D)          (None, 16, 16, 128)       73856
#
#  batch_normalization_13 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  activation_17 (Activation)  (None, 16, 16, 128)       0
#
#  conv2d_16 (Conv2D)          (None, 16, 16, 128)       147584
#
#  activation_18 (Activation)  (None, 16, 16, 128)       0
#
#  activation_19 (Activation)  (None, 16, 16, 128)       0
#
#  max_pooling2d_7 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  conv2d_17 (Conv2D)          (None, 8, 8, 256)         295168
#
#  batch_normalization_14 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_20 (Activation)  (None, 8, 8, 256)         0
#
#  conv2d_18 (Conv2D)          (None, 8, 8, 256)         590080
#
#  batch_normalization_15 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_21 (Activation)  (None, 8, 8, 256)         0
#
#  conv2d_19 (Conv2D)          (None, 4, 4, 512)         1180160
#
#  batch_normalization_16 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_22 (Activation)  (None, 4, 4, 512)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dropout_4 (Dropout)         (None, 8192)              0
#
#  fc1 (Dense)                 (None, 300)               2457900
#
#  dropout_5 (Dropout)         (None, 300)               0
#
#  output (Dense)              (None, 10)                3010
#
# =================================================================
# Total params: 4,791,598
# Trainable params: 4,789,038
# Non-trainable params: 2,560
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# 5번 iteration내에 validation loss가 향상되지 않으면 learning rate을 기존 learning rate * 0.2로 줄임.  
rlr_cb = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, mode='min', verbose=1)
# 10번 iteration내에 validation loss가 향상되지 않으면 더 이상 학습하지 않고 종료
ely_cb = EarlyStopping(monitor='val_loss', patience=10, mode='min', verbose=1)


history = model.fit(x=tr_images, y=tr_oh_labels, batch_size=32, epochs=30, shuffle=True,
                    validation_data=(val_images, val_oh_labels),  
                    callbacks=[rlr_cb, ely_cb] )
# Out:
# Epoch 1/30
# 1329/1329 [==============================] - 22s 11ms/step - loss: 1.6277 - accuracy: 0.4011 - val_loss: 1.6356 - val_accuracy: 0.4537 - lr: 0.0010
# Epoch 2/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 1.1737 - accuracy: 0.5783 - val_loss: 0.9556 - val_accuracy: 0.6552 - lr: 0.0010
# Epoch 3/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.9747 - accuracy: 0.6611 - val_loss: 1.1174 - val_accuracy: 0.6205 - lr: 0.0010
# Epoch 4/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.8362 - accuracy: 0.7129 - val_loss: 0.9854 - val_accuracy: 0.6783 - lr: 0.0010
# Epoch 5/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.7344 - accuracy: 0.7514 - val_loss: 0.7662 - val_accuracy: 0.7436 - lr: 0.0010
# Epoch 6/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.6396 - accuracy: 0.7864 - val_loss: 0.6021 - val_accuracy: 0.7965 - lr: 0.0010
# Epoch 7/30
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.5570 - accuracy: 0.8139 - val_loss: 0.6310 - val_accuracy: 0.7953 - lr: 0.0010
# Epoch 8/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.4871 - accuracy: 0.8393 - val_loss: 0.6282 - val_accuracy: 0.7975 - lr: 0.0010
# Epoch 9/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.4195 - accuracy: 0.8617 - val_loss: 0.7161 - val_accuracy: 0.7896 - lr: 0.0010
# Epoch 10/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.3604 - accuracy: 0.8823 - val_loss: 0.5149 - val_accuracy: 0.8349 - lr: 0.0010
# Epoch 11/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.3032 - accuracy: 0.9003 - val_loss: 0.6345 - val_accuracy: 0.8148 - lr: 0.0010
# Epoch 12/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.2587 - accuracy: 0.9134 - val_loss: 0.7345 - val_accuracy: 0.8043 - lr: 0.0010
# Epoch 13/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.2334 - accuracy: 0.9237 - val_loss: 0.6619 - val_accuracy: 0.8119 - lr: 0.0010
# Epoch 14/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.1934 - accuracy: 0.9359 - val_loss: 0.6832 - val_accuracy: 0.8165 - lr: 0.0010
# Epoch 15/30
# 1327/1329 [============================>.] - ETA: 0s - loss: 0.1739 - accuracy: 0.9421
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.1741 - accuracy: 0.9420 - val_loss: 0.6816 - val_accuracy: 0.8213 - lr: 0.0010
# Epoch 16/30
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.0759 - accuracy: 0.9749 - val_loss: 0.5854 - val_accuracy: 0.8683 - lr: 2.0000e-04
# Epoch 17/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.0431 - accuracy: 0.9856 - val_loss: 0.6792 - val_accuracy: 0.8667 - lr: 2.0000e-04
# Epoch 18/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.0343 - accuracy: 0.9886 - val_loss: 0.7085 - val_accuracy: 0.8679 - lr: 2.0000e-04
# Epoch 19/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.0285 - accuracy: 0.9902 - val_loss: 0.7581 - val_accuracy: 0.8656 - lr: 2.0000e-04
# Epoch 20/30
# 1327/1329 [============================>.] - ETA: 0s - loss: 0.0231 - accuracy: 0.9926
# Epoch 20: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.0232 - accuracy: 0.9926 - val_loss: 0.8712 - val_accuracy: 0.8611 - lr: 2.0000e-04
# Epoch 20: early stopping

# %%
model.evaluate(test_images, test_oh_labels)
show_history(history)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.9450 - accuracy: 0.8515

# %% [markdown]
# ### Global Average Pooling의 적용
# * Global Average Pooling은 피처맵의 가로x세로의 특정 영역을 Sub sampling 않고, 채널별로 평균 값을 추출
# * 충분히 Feature map의 채널수가 많을 경우 이를 적용. 채널수가 적다면 Flatten이 유리.
# * Flatten-> Classification Dense Layer로 이어지면서 많은 파라미터들로 인한 오버피팅 유발 가능성 증대 및 학습 시간 늘어남.
# * 맨 마지막 Feature Map의 채널 수가 충분히 크다면 GlobalAveragePooling2D를 적용하여 Flatten을 제거하는데 더 유리 할 수 있음.

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense , Conv2D , Dropout , Flatten , Activation, MaxPooling2D , GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam , RMSprop 
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau , EarlyStopping , ModelCheckpoint , LearningRateScheduler

input_tensor = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))

#x = Conv2D(filters=32, kernel_size=(5, 5), padding='valid', activation='relu')(input_tensor)
x = Conv2D(filters=64, kernel_size=(3, 3), padding='same')(input_tensor)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=64, kernel_size=(3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

x = Conv2D(filters=128, kernel_size=3, padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=128, kernel_size=3, padding='same')(x)
x = Activation('relu')(x)
x = Activation('relu')(x)
x = MaxPooling2D(pool_size=2)(x)

x = Conv2D(filters=256, kernel_size=3, padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=256, kernel_size=3, padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=512, kernel_size=3, strides=2, padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

# Flatten 대신 Global AveragePooling 을 적용. 
x = GlobalAveragePooling2D()(x)
x = Dropout(rate=0.5)(x)
x = Dense(50, activation='relu', name='fc1')(x)
x = Dropout(rate=0.2)(x)
output = Dense(10, activation='softmax', name='output')(x)

model = Model(inputs=input_tensor, outputs=output)

model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_20 (Conv2D)          (None, 32, 32, 64)        1792
#
#  batch_normalization_17 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  activation_23 (Activation)  (None, 32, 32, 64)        0
#
#  conv2d_21 (Conv2D)          (None, 32, 32, 64)        36928
#
#  batch_normalization_18 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  activation_24 (Activation)  (None, 32, 32, 64)        0
#
#  max_pooling2d_8 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_22 (Conv2D)          (None, 16, 16, 128)       73856
#
#  batch_normalization_19 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  activation_25 (Activation)  (None, 16, 16, 128)       0
#
#  conv2d_23 (Conv2D)          (None, 16, 16, 128)       147584
#
#  activation_26 (Activation)  (None, 16, 16, 128)       0
#
#  activation_27 (Activation)  (None, 16, 16, 128)       0
#
#  max_pooling2d_9 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  conv2d_24 (Conv2D)          (None, 8, 8, 256)         295168
#
#  batch_normalization_20 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_28 (Activation)  (None, 8, 8, 256)         0
#
#  conv2d_25 (Conv2D)          (None, 8, 8, 256)         590080
#
#  batch_normalization_21 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_29 (Activation)  (None, 8, 8, 256)         0
#
#  conv2d_26 (Conv2D)          (None, 4, 4, 512)         1180160
#
#  batch_normalization_22 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_30 (Activation)  (None, 4, 4, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout_6 (Dropout)         (None, 512)               0
#
#  fc1 (Dense)                 (None, 50)                25650
#
#  dropout_7 (Dropout)         (None, 50)                0
#
#  output (Dense)              (None, 10)                510
#
# =================================================================
# Total params: 2,356,848
# Trainable params: 2,354,288
# Non-trainable params: 2,560
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping

model.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# 5번 iteration내에 validation loss가 향상되지 않으면 learning rate을 기존 learning rate * 0.2로 줄임.  
rlr_cb = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, mode='min', verbose=1)
# 10번 iteration내에 validation loss가 향상되지 않으면 더 이상 학습하지 않고 종료
ely_cb = EarlyStopping(monitor='val_loss', patience=10, mode='min', verbose=1)


history = model.fit(x=tr_images, y=tr_oh_labels, batch_size=32, epochs=30, shuffle=True,
                    validation_data=(val_images, val_oh_labels),  
                    callbacks=[rlr_cb, ely_cb] )
# Out:
# Epoch 1/30
# 1329/1329 [==============================] - 20s 11ms/step - loss: 1.5118 - accuracy: 0.4461 - val_loss: 1.3971 - val_accuracy: 0.5140 - lr: 0.0010
# Epoch 2/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 1.0528 - accuracy: 0.6296 - val_loss: 0.8673 - val_accuracy: 0.6845 - lr: 0.0010
# Epoch 3/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.8536 - accuracy: 0.7078 - val_loss: 0.9856 - val_accuracy: 0.6657 - lr: 0.0010
# Epoch 4/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.7130 - accuracy: 0.7591 - val_loss: 0.9779 - val_accuracy: 0.6680 - lr: 0.0010
# Epoch 5/30
# 1329/1329 [==============================] - 14s 10ms/step - loss: 0.6039 - accuracy: 0.8005 - val_loss: 1.0235 - val_accuracy: 0.6765 - lr: 0.0010
# Epoch 6/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.5143 - accuracy: 0.8306 - val_loss: 0.6665 - val_accuracy: 0.7827 - lr: 0.0010
# Epoch 7/30
# 1329/1329 [==============================] - 14s 10ms/step - loss: 0.4447 - accuracy: 0.8526 - val_loss: 0.5830 - val_accuracy: 0.8081 - lr: 0.0010
# Epoch 8/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.3846 - accuracy: 0.8734 - val_loss: 0.6960 - val_accuracy: 0.7737 - lr: 0.0010
# Epoch 9/30
# 1329/1329 [==============================] - 14s 10ms/step - loss: 0.3279 - accuracy: 0.8917 - val_loss: 0.6751 - val_accuracy: 0.7912 - lr: 0.0010
# Epoch 10/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.2749 - accuracy: 0.9085 - val_loss: 0.5631 - val_accuracy: 0.8180 - lr: 0.0010
# Epoch 11/30
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.2354 - accuracy: 0.9225 - val_loss: 0.9503 - val_accuracy: 0.7671 - lr: 0.0010
# Epoch 12/30
# 1329/1329 [==============================] - 14s 10ms/step - loss: 0.2022 - accuracy: 0.9342 - val_loss: 0.7142 - val_accuracy: 0.8064 - lr: 0.0010
# Epoch 13/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.1694 - accuracy: 0.9433 - val_loss: 0.7837 - val_accuracy: 0.7947 - lr: 0.0010
# Epoch 14/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.1481 - accuracy: 0.9515 - val_loss: 0.5636 - val_accuracy: 0.8449 - lr: 0.0010
# Epoch 15/30
# 1328/1329 [============================>.] - ETA: 0s - loss: 0.1310 - accuracy: 0.9572
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.1313 - accuracy: 0.9571 - val_loss: 0.6211 - val_accuracy: 0.8403 - lr: 0.0010
# Epoch 16/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.0501 - accuracy: 0.9844 - val_loss: 0.5525 - val_accuracy: 0.8727 - lr: 2.0000e-04
# Epoch 17/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.0291 - accuracy: 0.9911 - val_loss: 0.6286 - val_accuracy: 0.8688 - lr: 2.0000e-04
# Epoch 18/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.0222 - accuracy: 0.9931 - val_loss: 0.6540 - val_accuracy: 0.8720 - lr: 2.0000e-04
# Epoch 19/30
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.0195 - accuracy: 0.9936 - val_loss: 0.6802 - val_accuracy: 0.8688 - lr: 2.0000e-04
# Epoch 20/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.0189 - accuracy: 0.9936 - val_loss: 0.7233 - val_accuracy: 0.8680 - lr: 2.0000e-04
# Epoch 21/30
# 1326/1329 [============================>.] - ETA: 0s - loss: 0.0154 - accuracy: 0.9951
# Epoch 21: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.0155 - accuracy: 0.9951 - val_loss: 0.7257 - val_accuracy: 0.8709 - lr: 2.0000e-04
# Epoch 22/30
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.0104 - accuracy: 0.9968 - val_loss: 0.6764 - val_accuracy: 0.8753 - lr: 4.0000e-05
# Epoch 23/30
# 1329/1329 [==============================] - 14s 10ms/step - loss: 0.0077 - accuracy: 0.9980 - val_loss: 0.6940 - val_accuracy: 0.8753 - lr: 4.0000e-05
# Epoch 24/30
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.0069 - accuracy: 0.9982 - val_loss: 0.7023 - val_accuracy: 0.8752 - lr: 4.0000e-05
# Epoch 25/30
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.0058 - accuracy: 0.9987 - val_loss: 0.7120 - val_accuracy: 0.8767 - lr: 4.0000e-05
# Epoch 26/30
# 1326/1329 [============================>.] - ETA: 0s - loss: 0.0056 - accuracy: 0.9987
# Epoch 26: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 1329/1329 [==============================] - 14s 11ms/step - loss: 0.0058 - accuracy: 0.9986 - val_loss: 0.7133 - val_accuracy: 0.8773 - lr: 4.0000e-05
# Epoch 26: early stopping

# %%
model.evaluate(test_images, test_oh_labels)
show_history(history)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.8014 - accuracy: 0.8674

# %% [markdown]
# ### 가중치 규제(Weight Regularizations)
# * 개별 layer별로 tensorflow.keras.regularizers의 l1, l2, l1_l2 를 이용하여 가중치 규제를 적용할 수 있음.

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense , Conv2D , Dropout , Flatten , Activation, MaxPooling2D , GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam , RMSprop 
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau , EarlyStopping , ModelCheckpoint , LearningRateScheduler
from tensorflow.keras.regularizers import l1, l2, l1_l2

input_tensor = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))

x = Conv2D(filters=64, kernel_size=(3, 3), padding='same', kernel_regularizer=l2(0.00001))(input_tensor)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=64, kernel_size=(3, 3), padding='same', kernel_regularizer=l2(0.00001))(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

x = Conv2D(filters=128, kernel_size=3, padding='same', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4))(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=128, kernel_size=3, padding='same', kernel_regularizer=l2(1e-5))(x)
x = Activation('relu')(x)
x = Activation('relu')(x)
x = MaxPooling2D(pool_size=2)(x)

x = Conv2D(filters=256, kernel_size=3, padding='same', kernel_regularizer=l2(1e-5))(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=256, kernel_size=3, padding='same', kernel_regularizer=l2(1e-5))(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

# 512 filters Conv layer 추가하되 이후 MaxPooling을 적용하지 않고 strides는 2로 변경하여 출력 feature map 크기 조정
x = Conv2D(filters=512, kernel_size=3, strides=2, padding='same', kernel_regularizer=l2(1e-5))(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)


# cifar10의 클래스가 10개 이므로 마지막 classification의 Dense layer units갯수는 10
x = Flatten(name='flatten')(x)
x = Dropout(rate=0.5)(x)
x = Dense(300, activation='relu', kernel_regularizer=l2(1e-5), name='fc1')(x)
x = Dropout(rate=0.3)(x)
output = Dense(10, activation='softmax', name='output')(x)

model = Model(inputs=input_tensor, outputs=output)

model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_27 (Conv2D)          (None, 32, 32, 64)        1792
#
#  batch_normalization_23 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  activation_31 (Activation)  (None, 32, 32, 64)        0
#
#  conv2d_28 (Conv2D)          (None, 32, 32, 64)        36928
#
#  batch_normalization_24 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  activation_32 (Activation)  (None, 32, 32, 64)        0
#
#  max_pooling2d_10 (MaxPoolin  (None, 16, 16, 64)       0
#  g2D)
#
#  conv2d_29 (Conv2D)          (None, 16, 16, 128)       73856
#
#  batch_normalization_25 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  activation_33 (Activation)  (None, 16, 16, 128)       0
#
#  conv2d_30 (Conv2D)          (None, 16, 16, 128)       147584
#
#  activation_34 (Activation)  (None, 16, 16, 128)       0
#
#  activation_35 (Activation)  (None, 16, 16, 128)       0
#
#  max_pooling2d_11 (MaxPoolin  (None, 8, 8, 128)        0
#  g2D)
#
#  conv2d_31 (Conv2D)          (None, 8, 8, 256)         295168
#
#  batch_normalization_26 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_36 (Activation)  (None, 8, 8, 256)         0
#
#  conv2d_32 (Conv2D)          (None, 8, 8, 256)         590080
#
#  batch_normalization_27 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  activation_37 (Activation)  (None, 8, 8, 256)         0
#
#  conv2d_33 (Conv2D)          (None, 4, 4, 512)         1180160
#
#  batch_normalization_28 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_38 (Activation)  (None, 4, 4, 512)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dropout_8 (Dropout)         (None, 8192)              0
#
#  fc1 (Dense)                 (None, 300)               2457900
#
#  dropout_9 (Dropout)         (None, 300)               0
#
#  output (Dense)              (None, 10)                3010
#
# =================================================================
# Total params: 4,791,598
# Trainable params: 4,789,038
# Non-trainable params: 2,560
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# 5번 iteration내에 validation loss가 향상되지 않으면 learning rate을 기존 learning rate * 0.2로 줄임.  
rlr_cb = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, mode='min', verbose=1)
# 10번 iteration내에 validation loss가 향상되지 않으면 더 이상 학습하지 않고 종료
ely_cb = EarlyStopping(monitor='val_loss', patience=10, mode='min', verbose=1)


history = model.fit(x=tr_images, y=tr_oh_labels, batch_size=32, epochs=30, shuffle=True,
                    validation_data=(val_images, val_oh_labels),  
                    callbacks=[rlr_cb, ely_cb] )
# Out:
# Epoch 1/30
# 1329/1329 [==============================] - 20s 11ms/step - loss: 1.6730 - accuracy: 0.3992 - val_loss: 1.2991 - val_accuracy: 0.5596 - lr: 0.0010
# Epoch 2/30
# 1329/1329 [==============================] - 15s 11ms/step - loss: 1.2272 - accuracy: 0.5863 - val_loss: 1.2667 - val_accuracy: 0.5823 - lr: 0.0010
# Epoch 3/30
# 1329/1329 [==============================] - 15s 11ms/step - loss: 1.0380 - accuracy: 0.6654 - val_loss: 1.2936 - val_accuracy: 0.6100 - lr: 0.0010
# Epoch 4/30
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.9369 - accuracy: 0.7138 - val_loss: 0.8235 - val_accuracy: 0.7535 - lr: 0.0010
# Epoch 5/30
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.8485 - accuracy: 0.7501 - val_loss: 0.8624 - val_accuracy: 0.7528 - lr: 0.0010
# Epoch 6/30
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.7795 - accuracy: 0.7858 - val_loss: 0.8956 - val_accuracy: 0.7565 - lr: 0.0010
# Epoch 7/30
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.7260 - accuracy: 0.8124 - val_loss: 0.9047 - val_accuracy: 0.7721 - lr: 0.0010
# Epoch 8/30
# 1329/1329 [==============================] - 15s 12ms/step - loss: 0.6782 - accuracy: 0.8360 - val_loss: 0.8505 - val_accuracy: 0.7812 - lr: 0.0010
# Epoch 9/30
# 1328/1329 [============================>.] - ETA: 0s - loss: 0.6388 - accuracy: 0.8556
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.6388 - accuracy: 0.8556 - val_loss: 0.8885 - val_accuracy: 0.7907 - lr: 0.0010
# Epoch 10/30
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.4597 - accuracy: 0.9146 - val_loss: 0.6699 - val_accuracy: 0.8612 - lr: 2.0000e-04
# Epoch 11/30
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.3833 - accuracy: 0.9375 - val_loss: 0.6839 - val_accuracy: 0.8633 - lr: 2.0000e-04
# Epoch 12/30
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.3429 - accuracy: 0.9495 - val_loss: 0.7281 - val_accuracy: 0.8580 - lr: 2.0000e-04
# Epoch 13/30
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.3095 - accuracy: 0.9584 - val_loss: 0.7300 - val_accuracy: 0.8648 - lr: 2.0000e-04
# Epoch 14/30
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.2822 - accuracy: 0.9667 - val_loss: 0.7724 - val_accuracy: 0.8624 - lr: 2.0000e-04
# Epoch 15/30
# 1329/1329 [==============================] - ETA: 0s - loss: 0.2642 - accuracy: 0.9714
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.2642 - accuracy: 0.9714 - val_loss: 0.8504 - val_accuracy: 0.8572 - lr: 2.0000e-04
# Epoch 16/30
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.2296 - accuracy: 0.9841 - val_loss: 0.7727 - val_accuracy: 0.8737 - lr: 4.0000e-05
# Epoch 17/30
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.2162 - accuracy: 0.9876 - val_loss: 0.7957 - val_accuracy: 0.8769 - lr: 4.0000e-05
# Epoch 18/30
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.2109 - accuracy: 0.9892 - val_loss: 0.8226 - val_accuracy: 0.8741 - lr: 4.0000e-05
# Epoch 19/30
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.2053 - accuracy: 0.9906 - val_loss: 0.8357 - val_accuracy: 0.8752 - lr: 4.0000e-05
# Epoch 20/30
# 1328/1329 [============================>.] - ETA: 0s - loss: 0.2022 - accuracy: 0.9916
# Epoch 20: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 1329/1329 [==============================] - 15s 11ms/step - loss: 0.2022 - accuracy: 0.9916 - val_loss: 0.8545 - val_accuracy: 0.8763 - lr: 4.0000e-05
# Epoch 20: early stopping

# %%
model.evaluate(test_images, test_oh_labels)
show_history(history)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.9257 - accuracy: 0.8602
